# %% [markdown]
# ## Importing the Libraries

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam, SGD
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('../input/*/trainx/*.bmp'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('../input/*/trainy/*.bmp'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
epsilon = 1e-5
smooth = 1

def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def focal_tversky(y_true,y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.75
    return K.pow((1-pt_1), gamma)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
        return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
def img_augmentation(x_test, y_test):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_test)):
        x,y = random_rotation(x_test[idx], y_test[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_test[idx], y_test[idx])
        x_flip.append(x)
        y_flip.append(y)

    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)
x_rotated_t, y_rotated_t, x_flipped_t, y_flipped_t = img_augmentation(x_test, y_test)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 114
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
# For training Set
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt SGD optimization algorithm, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * On large datasets, SGD can converge faster than batch training because it performs updates more frequently. We can get away with this because the data often contains redundant information, so the gradient can be reasonably approximated without using the full dataset. Minibatch training can be faster than training on single data points because it can take advantage of vectorized operations to process the entire minibatch at once. The stochastic nature of online/minibatch training can also make it possible to hop out of local minima that might otherwise trap batch training.
# * The learning rate is the conventional 0.001.

# %% [markdown]
# ### Model Function

# %%
# earlystopping = EarlyStopping(monitor='val_loss',
#                               mode='min', 
#                               verbose=1, 
#                               patience=30
#                              )
# # save the best model with lower validation loss
# checkpointer = ModelCheckpoint(filepath="=unet_vgg19_100_epoch.h5", 
#                                verbose=1, 
#                                save_best_only=True
#                               )
# reduce_lr = ReduceLROnPlateau(monitor='val_loss',
#                               mode='min',
#                               verbose=1,
#                               patience=10,
#                               min_delta=0.0001,
#                               factor=0.2
#                              )

# %%
# pip install -U git+https://github.com/qubvel/efficientnet/tree/v0.0.4

# %%
# pip install -U efficientnet==0.0.4

# %%
# pip install -U git+https://github.com/qubvel/efficientnet

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input

# import efficientnet.keras
import efficientnet.tfkeras as effnet 
# import efficientnet as effnet
# from keras_efficientnets import EfficientNetB0
# from efficientnets import EfficientNetB0

from tensorflow.keras.layers import Activation, SpatialDropout2D
from tensorflow.keras.layers import concatenate

# %%
from efficientnet.tfkeras import EfficientNetB4

# %%
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Input,Dropout,BatchNormalization,Activation,Add

# %%
def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    x = BatchNormalization()(x)
    if activation == True:
        x = LeakyReLU(alpha=0.1)(x)
    return x

def residual_block(blockInput, num_filters=16):
    x = LeakyReLU(alpha=0.1)(blockInput)
    x = BatchNormalization()(x)
    blockInput = BatchNormalization()(blockInput)
    x = convolution_block(x, num_filters, (3,3) )
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    return x

# %%
from tensorflow.keras.applications import MobileNetV2

# %%
print("TF Version: ", tf.__version__)

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip])
    x = conv_block(x, num_filters)

    return x

def build_mobilenetv2_unet(input_shape,epochs_num):    ## (512, 512, 3)
    """ Input """
    inputs = Input(shape=input_shape,name="input_image")

    """ Pre-trained MobileNetV2 """
    encoder = MobileNetV2(include_top=False, weights="imagenet",
        input_tensor=inputs, alpha=1.4)

    """ Encoder """
    s1 = encoder.get_layer("input_image").output                ## (512 x 512)
    s2 = encoder.get_layer("block_1_expand_relu").output    ## (256 x 256)
    s3 = encoder.get_layer("block_3_expand_relu").output    ## (128 x 128)
    s4 = encoder.get_layer("block_6_expand_relu").output    ## (64 x 64)

    """ Bridge """
    b1 = encoder.get_layer("block_13_expand_relu").output   ## (32 x 32)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)                         ## (64 x 64)
    d2 = decoder_block(d1, s3, 256)                         ## (128 x 128)
    d3 = decoder_block(d2, s2, 128)                         ## (256 x 256)
    d4 = decoder_block(d3, s1, 64)                          ## (512 x 512)

    """ Output """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    pred = Reshape((192,256))(outputs)
    model = Model(inputs, pred, name="MobileNetV2_U-Net")
    adam = tf.keras.optimizers.Adam(lr = 0.05, epsilon = 0.1)
    model.compile(optimizer = adam, loss= ["binary_crossentropy"]
                      , metrics=[iou, dice_coef, precision, recall, accuracy,tversky])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)

    model.save("MobileNet_UNET")
    return model,hist


model,hist = build_mobilenetv2_unet((192,256,3),60)
# model,hist = build_efficientnet_unet((192,256,3),60)
# Out:
# TF Version:  1.14.0
# Model: "MobileNetV2_U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 192, 256, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 193, 257, 3)  0           input_image[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 96, 128, 48)  1296        Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 96, 128, 48)  192         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 96, 128, 48)  0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 96, 128, 48)  432         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 96, 128, 48)  192         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 96, 128, 48)  0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 96, 128, 24)  1152        expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 96, 128, 24)  96          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 96, 128, 144) 3456        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 96, 128, 144) 576         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 96, 128, 144) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 97, 129, 144) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 48, 64, 144)  1296        block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 48, 64, 144)  576         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 48, 64, 144)  0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 48, 64, 32)   4608        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 48, 64, 32)   128         block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 48, 64, 192)  6144        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 48, 64, 192)  768         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 48, 64, 192)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 48, 64, 192)  1728        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 48, 64, 192)  768         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 48, 64, 192)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 48, 64, 32)   6144        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 48, 64, 32)   128         block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 48, 64, 32)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 48, 64, 192)  6144        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 48, 64, 192)  768         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 48, 64, 192)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 49, 65, 192)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 24, 32, 192)  1728        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 24, 32, 192)  768         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 24, 32, 192)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 24, 32, 48)   9216        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 24, 32, 48)   192         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 24, 32, 288)  13824       block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 24, 32, 288)  1152        block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 24, 32, 288)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 24, 32, 288)  2592        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 24, 32, 288)  1152        block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 24, 32, 288)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 24, 32, 48)   13824       block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 24, 32, 48)   192         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 24, 32, 48)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 24, 32, 288)  13824       block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 24, 32, 288)  1152        block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 24, 32, 288)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 24, 32, 288)  2592        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 24, 32, 288)  1152        block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 24, 32, 288)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 24, 32, 48)   13824       block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 24, 32, 48)   192         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 24, 32, 48)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 24, 32, 288)  13824       block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 24, 32, 288)  1152        block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 24, 32, 288)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 25, 33, 288)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 12, 16, 288)  2592        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 12, 16, 288)  1152        block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 12, 16, 288)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 12, 16, 88)   25344       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 12, 16, 88)   352         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 12, 16, 528)  46464       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 12, 16, 528)  2112        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 12, 16, 528)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 12, 16, 528)  4752        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 12, 16, 528)  2112        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 12, 16, 528)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 12, 16, 88)   46464       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 12, 16, 88)   352         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 12, 16, 88)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 12, 16, 528)  46464       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 12, 16, 528)  2112        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 12, 16, 528)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 12, 16, 528)  4752        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 12, 16, 528)  2112        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 12, 16, 528)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 12, 16, 88)   46464       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 12, 16, 88)   352         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 12, 16, 88)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 12, 16, 528)  46464       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 12, 16, 528)  2112        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 12, 16, 528)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 12, 16, 528)  4752        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 12, 16, 528)  2112        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 12, 16, 528)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 12, 16, 88)   46464       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 12, 16, 88)   352         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 12, 16, 88)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 12, 16, 528)  46464       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 12, 16, 528)  2112        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 12, 16, 528)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 12, 16, 528)  4752        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 12, 16, 528)  2112        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 12, 16, 528)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 12, 16, 136)  71808       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 12, 16, 136)  544         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 12, 16, 816)  110976      block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 12, 16, 816)  3264        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 12, 16, 816)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 12, 16, 816)  7344        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 12, 16, 816)  3264        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 12, 16, 816)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 12, 16, 136)  110976      block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 12, 16, 136)  544         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 12, 16, 136)  0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 12, 16, 816)  110976      block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 12, 16, 816)  3264        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 12, 16, 816)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 12, 16, 816)  7344        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 12, 16, 816)  3264        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 12, 16, 816)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 12, 16, 136)  110976      block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 12, 16, 136)  544         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 12, 16, 136)  0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 12, 16, 816)  110976      block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 12, 16, 816)  3264        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 12, 16, 816)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_29 (Conv2DTran (None, 24, 32, 512)  1671680     block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 24, 32, 800)  0           conv2d_transpose_29[0][0]
#                                                                  block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 24, 32, 512)  3686912     concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 24, 32, 512)  2048        conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 24, 32, 512)  0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 24, 32, 512)  2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 24, 32, 512)  2048        conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 24, 32, 512)  0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_30 (Conv2DTran (None, 48, 64, 256)  524544      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 48, 64, 448)  0           conv2d_transpose_30[0][0]
#                                                                  block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 48, 64, 256)  1032448     concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 48, 64, 256)  1024        conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 48, 64, 256)  0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 48, 64, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 48, 64, 256)  1024        conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 48, 64, 256)  0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_31 (Conv2DTran (None, 96, 128, 128) 131200      activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 96, 128, 272) 0           conv2d_transpose_31[0][0]
#                                                                  block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 96, 128, 128) 313472      concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 96, 128, 128) 512         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 96, 128, 128) 0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 96, 128, 128) 147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 96, 128, 128) 512         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 96, 128, 128) 0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_32 (Conv2DTran (None, 192, 256, 64) 32832       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 192, 256, 67) 0           conv2d_transpose_32[0][0]
#                                                                  input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 192, 256, 64) 38656       concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 192, 256, 64) 256         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 192, 256, 64) 0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 192, 256, 64) 36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 192, 256, 64) 256         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 192, 256, 64) 0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 192, 256, 1)  65          activation_15[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 192, 256)     0           conv2d_76[0][0]
# ==================================================================================================
# Total params: 11,753,809
# Trainable params: 11,725,617
# Non-trainable params: 28,192
# __________________________________________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/60
# 360/360 [==============================] - 27s 74ms/sample - loss: 0.4289 - iou: 0.8217 - dice_coef: 0.5680 - precision: 0.7355 - recall: 0.6542 - accuracy: 0.8102 - tversky: 0.5824 - val_loss: 2.4677 - val_iou: 0.6531 - val_dice_coef: 0.0176 - val_precision: 0.1368 - val_recall: 8.5229e-05 - val_accuracy: 0.6871 - val_tversky: 0.0128
# Epoch 2/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.3343 - iou: 0.8657 - dice_coef: 0.6524 - precision: 0.8448 - recall: 0.7011 - accuracy: 0.8593 - tversky: 0.6518 - val_loss: 1.1487 - val_iou: 0.6950 - val_dice_coef: 0.1765 - val_precision: 0.7505 - val_recall: 0.0319 - val_accuracy: 0.6954 - val_tversky: 0.1382
# Epoch 3/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.3274 - iou: 0.8717 - dice_coef: 0.6824 - precision: 0.8347 - recall: 0.7256 - accuracy: 0.8615 - tversky: 0.6834 - val_loss: 0.6682 - val_iou: 0.7647 - val_dice_coef: 0.3921 - val_precision: 0.8821 - val_recall: 0.2201 - val_accuracy: 0.7473 - val_tversky: 0.3358
# Epoch 4/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.3161 - iou: 0.8733 - dice_coef: 0.6868 - precision: 0.8326 - recall: 0.7391 - accuracy: 0.8649 - tversky: 0.6908 - val_loss: 0.5959 - val_iou: 0.7862 - val_dice_coef: 0.4419 - val_precision: 0.9395 - val_recall: 0.2825 - val_accuracy: 0.7730 - val_tversky: 0.3827
# Epoch 5/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.3114 - iou: 0.8760 - dice_coef: 0.6968 - precision: 0.8290 - recall: 0.7396 - accuracy: 0.8648 - tversky: 0.6977 - val_loss: 0.5813 - val_iou: 0.7784 - val_dice_coef: 0.4081 - val_precision: 0.9836 - val_recall: 0.2067 - val_accuracy: 0.7485 - val_tversky: 0.3505
# Epoch 6/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.3138 - iou: 0.8742 - dice_coef: 0.6910 - precision: 0.8312 - recall: 0.7306 - accuracy: 0.8643 - tversky: 0.6902 - val_loss: 0.6710 - val_iou: 0.7738 - val_dice_coef: 0.4031 - val_precision: 0.9941 - val_recall: 0.2177 - val_accuracy: 0.7546 - val_tversky: 0.3413
# Epoch 7/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.3164 - iou: 0.8745 - dice_coef: 0.6931 - precision: 0.8212 - recall: 0.7516 - accuracy: 0.8623 - tversky: 0.6958 - val_loss: 0.4494 - val_iou: 0.8322 - val_dice_coef: 0.5730 - val_precision: 0.9686 - val_recall: 0.4491 - val_accuracy: 0.8267 - val_tversky: 0.5229
# Epoch 8/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.3083 - iou: 0.8780 - dice_coef: 0.6967 - precision: 0.8472 - recall: 0.7316 - accuracy: 0.8694 - tversky: 0.6956 - val_loss: 0.3064 - val_iou: 0.8737 - val_dice_coef: 0.7256 - val_precision: 0.7343 - val_recall: 0.8561 - val_accuracy: 0.8590 - val_tversky: 0.7542
# Epoch 9/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.3126 - iou: 0.8742 - dice_coef: 0.6958 - precision: 0.8158 - recall: 0.7651 - accuracy: 0.8641 - tversky: 0.7020 - val_loss: 1.1677 - val_iou: 0.6849 - val_dice_coef: 0.5909 - val_precision: 0.4316 - val_recall: 0.9931 - val_accuracy: 0.5857 - val_tversky: 0.7007
# Epoch 10/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.3109 - iou: 0.8785 - dice_coef: 0.7023 - precision: 0.8386 - recall: 0.7457 - accuracy: 0.8692 - tversky: 0.7027 - val_loss: 0.6434 - val_iou: 0.7844 - val_dice_coef: 0.6685 - val_precision: 0.5636 - val_recall: 0.9696 - val_accuracy: 0.7534 - val_tversky: 0.7543
# Epoch 11/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.3020 - iou: 0.8815 - dice_coef: 0.7072 - precision: 0.8278 - recall: 0.7684 - accuracy: 0.8695 - tversky: 0.7135 - val_loss: 0.8083 - val_iou: 0.7452 - val_dice_coef: 0.6392 - val_precision: 0.4927 - val_recall: 0.9805 - val_accuracy: 0.6777 - val_tversky: 0.7344
# Epoch 12/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.3096 - iou: 0.8789 - dice_coef: 0.7044 - precision: 0.8432 - recall: 0.7635 - accuracy: 0.8732 - tversky: 0.7081 - val_loss: 1.8736 - val_iou: 0.5860 - val_dice_coef: 0.5224 - val_precision: 0.3454 - val_recall: 0.9994 - val_accuracy: 0.4099 - val_tversky: 0.6428
# Epoch 13/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.2965 - iou: 0.8827 - dice_coef: 0.7068 - precision: 0.8551 - recall: 0.7463 - accuracy: 0.8749 - tversky: 0.7060 - val_loss: 1.7713 - val_iou: 0.6410 - val_dice_coef: 0.5672 - val_precision: 0.3926 - val_recall: 0.9978 - val_accuracy: 0.5178 - val_tversky: 0.6840
# Epoch 14/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.3085 - iou: 0.8824 - dice_coef: 0.7217 - precision: 0.8285 - recall: 0.7783 - accuracy: 0.8723 - tversky: 0.7264 - val_loss: 4.0485 - val_iou: 0.5164 - val_dice_coef: 0.4815 - val_precision: 0.3160 - val_recall: 1.0000 - val_accuracy: 0.3222 - val_tversky: 0.6060
# Epoch 15/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.2895 - iou: 0.8891 - dice_coef: 0.7177 - precision: 0.8651 - recall: 0.7616 - accuracy: 0.8822 - tversky: 0.7163 - val_loss: 1.5349 - val_iou: 0.6329 - val_dice_coef: 0.5556 - val_precision: 0.3763 - val_recall: 0.9984 - val_accuracy: 0.4801 - val_tversky: 0.6724
# Epoch 16/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.2500 - iou: 0.9025 - dice_coef: 0.7574 - precision: 0.8766 - recall: 0.8046 - accuracy: 0.8976 - tversky: 0.7641 - val_loss: 4.2323 - val_iou: 0.5199 - val_dice_coef: 0.4846 - val_precision: 0.3171 - val_recall: 1.0000 - val_accuracy: 0.3260 - val_tversky: 0.6094
# Epoch 17/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.2433 - iou: 0.9070 - dice_coef: 0.7714 - precision: 0.8918 - recall: 0.8021 - accuracy: 0.9027 - tversky: 0.7701 - val_loss: 3.0674 - val_iou: 0.5556 - val_dice_coef: 0.5073 - val_precision: 0.3354 - val_recall: 0.9998 - val_accuracy: 0.3788 - val_tversky: 0.6295
# Epoch 18/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.2380 - iou: 0.9070 - dice_coef: 0.7655 - precision: 0.8700 - recall: 0.8214 - accuracy: 0.9017 - tversky: 0.7722 - val_loss: 4.8827 - val_iou: 0.5262 - val_dice_coef: 0.4912 - val_precision: 0.3284 - val_recall: 0.9990 - val_accuracy: 0.3607 - val_tversky: 0.6150
# Epoch 19/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.2281 - iou: 0.9142 - dice_coef: 0.7817 - precision: 0.8931 - recall: 0.8292 - accuracy: 0.9102 - tversky: 0.7846 - val_loss: 3.5638 - val_iou: 0.5345 - val_dice_coef: 0.4967 - val_precision: 0.3318 - val_recall: 0.9998 - val_accuracy: 0.3695 - val_tversky: 0.6200
# Epoch 20/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.1862 - iou: 0.9315 - dice_coef: 0.8278 - precision: 0.9130 - recall: 0.8701 - accuracy: 0.9302 - tversky: 0.8301 - val_loss: 0.4927 - val_iou: 0.8141 - val_dice_coef: 0.5162 - val_precision: 0.9865 - val_recall: 0.3320 - val_accuracy: 0.7900 - val_tversky: 0.4457
# Epoch 21/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.1730 - iou: 0.9376 - dice_coef: 0.8416 - precision: 0.9160 - recall: 0.8868 - accuracy: 0.9354 - tversky: 0.8444 - val_loss: 0.4855 - val_iou: 0.8360 - val_dice_coef: 0.6293 - val_precision: 0.8642 - val_recall: 0.5164 - val_accuracy: 0.8231 - val_tversky: 0.5743
# Epoch 22/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.1611 - iou: 0.9427 - dice_coef: 0.8582 - precision: 0.9241 - recall: 0.8932 - accuracy: 0.9395 - tversky: 0.8602 - val_loss: 0.2224 - val_iou: 0.9123 - val_dice_coef: 0.7826 - val_precision: 0.9041 - val_recall: 0.8023 - val_accuracy: 0.9099 - val_tversky: 0.7823
# Epoch 23/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.1363 - iou: 0.9508 - dice_coef: 0.8747 - precision: 0.9406 - recall: 0.9017 - accuracy: 0.9489 - tversky: 0.8739 - val_loss: 0.7964 - val_iou: 0.7245 - val_dice_coef: 0.6158 - val_precision: 0.4519 - val_recall: 0.9980 - val_accuracy: 0.6181 - val_tversky: 0.7214
# Epoch 24/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.1027 - iou: 0.9623 - dice_coef: 0.9000 - precision: 0.9445 - recall: 0.9398 - accuracy: 0.9616 - tversky: 0.9051 - val_loss: 2.2868 - val_iou: 0.5487 - val_dice_coef: 0.5089 - val_precision: 0.3324 - val_recall: 1.0000 - val_accuracy: 0.3715 - val_tversky: 0.6325
# Epoch 25/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0743 - iou: 0.9725 - dice_coef: 0.9300 - precision: 0.9568 - recall: 0.9559 - accuracy: 0.9717 - tversky: 0.9336 - val_loss: 4.1433 - val_iou: 0.5160 - val_dice_coef: 0.4830 - val_precision: 0.3174 - val_recall: 1.0000 - val_accuracy: 0.3269 - val_tversky: 0.6076
# Epoch 26/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0708 - iou: 0.9737 - dice_coef: 0.9367 - precision: 0.9624 - recall: 0.9551 - accuracy: 0.9729 - tversky: 0.9382 - val_loss: 3.2334 - val_iou: 0.5334 - val_dice_coef: 0.4944 - val_precision: 0.3241 - val_recall: 1.0000 - val_accuracy: 0.3480 - val_tversky: 0.6182
# Epoch 27/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0730 - iou: 0.9726 - dice_coef: 0.9376 - precision: 0.9625 - recall: 0.9529 - accuracy: 0.9720 - tversky: 0.9384 - val_loss: 0.5074 - val_iou: 0.8453 - val_dice_coef: 0.7501 - val_precision: 0.6518 - val_recall: 0.9838 - val_accuracy: 0.8289 - val_tversky: 0.8260
# Epoch 28/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0610 - iou: 0.9771 - dice_coef: 0.9408 - precision: 0.9672 - recall: 0.9630 - accuracy: 0.9773 - tversky: 0.9425 - val_loss: 1.2570 - val_iou: 0.6592 - val_dice_coef: 0.5748 - val_precision: 0.3941 - val_recall: 0.9988 - val_accuracy: 0.5240 - val_tversky: 0.6892
# Epoch 29/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.0573 - iou: 0.9783 - dice_coef: 0.9485 - precision: 0.9626 - recall: 0.9704 - accuracy: 0.9781 - tversky: 0.9517 - val_loss: 0.8459 - val_iou: 0.7233 - val_dice_coef: 0.6236 - val_precision: 0.4628 - val_recall: 0.9990 - val_accuracy: 0.6297 - val_tversky: 0.7276
# Epoch 30/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0438 - iou: 0.9833 - dice_coef: 0.9577 - precision: 0.9769 - recall: 0.9705 - accuracy: 0.9828 - tversky: 0.9578 - val_loss: 1.3514 - val_iou: 0.6249 - val_dice_coef: 0.5599 - val_precision: 0.3733 - val_recall: 0.9999 - val_accuracy: 0.4732 - val_tversky: 0.6778
# Epoch 31/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.0392 - iou: 0.9846 - dice_coef: 0.9631 - precision: 0.9747 - recall: 0.9775 - accuracy: 0.9845 - tversky: 0.9647 - val_loss: 0.6310 - val_iou: 0.7774 - val_dice_coef: 0.6783 - val_precision: 0.5389 - val_recall: 0.9985 - val_accuracy: 0.7271 - val_tversky: 0.7746
# Epoch 32/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0488 - iou: 0.9818 - dice_coef: 0.9569 - precision: 0.9719 - recall: 0.9717 - accuracy: 0.9810 - tversky: 0.9581 - val_loss: 0.2229 - val_iou: 0.9353 - val_dice_coef: 0.8491 - val_precision: 0.9778 - val_recall: 0.7957 - val_accuracy: 0.9316 - val_tversky: 0.8129
# Epoch 33/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.0498 - iou: 0.9812 - dice_coef: 0.9562 - precision: 0.9680 - recall: 0.9742 - accuracy: 0.9811 - tversky: 0.9589 - val_loss: 0.1502 - val_iou: 0.9513 - val_dice_coef: 0.8950 - val_precision: 0.9479 - val_recall: 0.8831 - val_accuracy: 0.9490 - val_tversky: 0.8855
# Epoch 34/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0486 - iou: 0.9818 - dice_coef: 0.9552 - precision: 0.9703 - recall: 0.9734 - accuracy: 0.9814 - tversky: 0.9570 - val_loss: 0.1953 - val_iou: 0.9452 - val_dice_coef: 0.8898 - val_precision: 0.9238 - val_recall: 0.8943 - val_accuracy: 0.9437 - val_tversky: 0.8865
# Epoch 35/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0430 - iou: 0.9832 - dice_coef: 0.9601 - precision: 0.9732 - recall: 0.9747 - accuracy: 0.9832 - tversky: 0.9614 - val_loss: 0.1255 - val_iou: 0.9565 - val_dice_coef: 0.8933 - val_precision: 0.9477 - val_recall: 0.9039 - val_accuracy: 0.9531 - val_tversky: 0.8880
# Epoch 36/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0367 - iou: 0.9856 - dice_coef: 0.9646 - precision: 0.9752 - recall: 0.9798 - accuracy: 0.9857 - tversky: 0.9663 - val_loss: 0.1476 - val_iou: 0.9479 - val_dice_coef: 0.8909 - val_precision: 0.9091 - val_recall: 0.9208 - val_accuracy: 0.9446 - val_tversky: 0.8966
# Epoch 37/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.0410 - iou: 0.9837 - dice_coef: 0.9623 - precision: 0.9770 - recall: 0.9722 - accuracy: 0.9837 - tversky: 0.9619 - val_loss: 0.1953 - val_iou: 0.9315 - val_dice_coef: 0.8684 - val_precision: 0.8367 - val_recall: 0.9555 - val_accuracy: 0.9267 - val_tversky: 0.8945
# Epoch 38/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0326 - iou: 0.9870 - dice_coef: 0.9682 - precision: 0.9785 - recall: 0.9811 - accuracy: 0.9869 - tversky: 0.9692 - val_loss: 0.2441 - val_iou: 0.9147 - val_dice_coef: 0.8424 - val_precision: 0.7814 - val_recall: 0.9756 - val_accuracy: 0.9065 - val_tversky: 0.8855
# Epoch 39/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0332 - iou: 0.9869 - dice_coef: 0.9679 - precision: 0.9773 - recall: 0.9814 - accuracy: 0.9868 - tversky: 0.9692 - val_loss: 0.1504 - val_iou: 0.9521 - val_dice_coef: 0.8982 - val_precision: 0.9347 - val_recall: 0.9048 - val_accuracy: 0.9497 - val_tversky: 0.8921
# Epoch 40/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0344 - iou: 0.9865 - dice_coef: 0.9683 - precision: 0.9767 - recall: 0.9809 - accuracy: 0.9863 - tversky: 0.9694 - val_loss: 0.2749 - val_iou: 0.9012 - val_dice_coef: 0.8146 - val_precision: 0.7485 - val_recall: 0.9847 - val_accuracy: 0.8928 - val_tversky: 0.8694
# Epoch 41/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0337 - iou: 0.9867 - dice_coef: 0.9685 - precision: 0.9772 - recall: 0.9818 - accuracy: 0.9869 - tversky: 0.9699 - val_loss: 0.2557 - val_iou: 0.9067 - val_dice_coef: 0.8228 - val_precision: 0.7571 - val_recall: 0.9845 - val_accuracy: 0.8977 - val_tversky: 0.8753
# Epoch 42/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0285 - iou: 0.9885 - dice_coef: 0.9719 - precision: 0.9816 - recall: 0.9829 - accuracy: 0.9887 - tversky: 0.9726 - val_loss: 0.3900 - val_iou: 0.8681 - val_dice_coef: 0.7827 - val_precision: 0.6856 - val_recall: 0.9935 - val_accuracy: 0.8561 - val_tversky: 0.8529
# Epoch 43/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0285 - iou: 0.9886 - dice_coef: 0.9731 - precision: 0.9804 - recall: 0.9842 - accuracy: 0.9886 - tversky: 0.9740 - val_loss: 0.1669 - val_iou: 0.9402 - val_dice_coef: 0.8767 - val_precision: 0.8469 - val_recall: 0.9820 - val_accuracy: 0.9388 - val_tversky: 0.9101
# Epoch 44/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.0305 - iou: 0.9877 - dice_coef: 0.9713 - precision: 0.9799 - recall: 0.9827 - accuracy: 0.9879 - tversky: 0.9722 - val_loss: 0.3909 - val_iou: 0.8591 - val_dice_coef: 0.7729 - val_precision: 0.6645 - val_recall: 0.9964 - val_accuracy: 0.8416 - val_tversky: 0.8464
# Epoch 45/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0282 - iou: 0.9885 - dice_coef: 0.9734 - precision: 0.9812 - recall: 0.9833 - accuracy: 0.9885 - tversky: 0.9740 - val_loss: 0.2375 - val_iou: 0.9154 - val_dice_coef: 0.8516 - val_precision: 0.7757 - val_recall: 0.9907 - val_accuracy: 0.9104 - val_tversky: 0.8994
# Epoch 46/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0255 - iou: 0.9896 - dice_coef: 0.9752 - precision: 0.9821 - recall: 0.9856 - accuracy: 0.9896 - tversky: 0.9760 - val_loss: 0.1699 - val_iou: 0.9404 - val_dice_coef: 0.8958 - val_precision: 0.8512 - val_recall: 0.9867 - val_accuracy: 0.9402 - val_tversky: 0.9270
# Epoch 47/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0245 - iou: 0.9901 - dice_coef: 0.9761 - precision: 0.9826 - recall: 0.9865 - accuracy: 0.9902 - tversky: 0.9772 - val_loss: 0.5449 - val_iou: 0.8376 - val_dice_coef: 0.7610 - val_precision: 0.6350 - val_recall: 0.9977 - val_accuracy: 0.8208 - val_tversky: 0.8394
# Epoch 48/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.0225 - iou: 0.9908 - dice_coef: 0.9783 - precision: 0.9853 - recall: 0.9860 - accuracy: 0.9908 - tversky: 0.9785 - val_loss: 0.1066 - val_iou: 0.9655 - val_dice_coef: 0.9206 - val_precision: 0.9588 - val_recall: 0.9209 - val_accuracy: 0.9628 - val_tversky: 0.9120
# Epoch 49/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.0282 - iou: 0.9886 - dice_coef: 0.9736 - precision: 0.9802 - recall: 0.9845 - accuracy: 0.9888 - tversky: 0.9749 - val_loss: 0.1367 - val_iou: 0.9531 - val_dice_coef: 0.9120 - val_precision: 0.8761 - val_recall: 0.9845 - val_accuracy: 0.9535 - val_tversky: 0.9363
# Epoch 50/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0245 - iou: 0.9900 - dice_coef: 0.9757 - precision: 0.9829 - recall: 0.9856 - accuracy: 0.9901 - tversky: 0.9764 - val_loss: 0.2100 - val_iou: 0.9298 - val_dice_coef: 0.8796 - val_precision: 0.8188 - val_recall: 0.9910 - val_accuracy: 0.9293 - val_tversky: 0.9180
# Epoch 51/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.0221 - iou: 0.9910 - dice_coef: 0.9787 - precision: 0.9841 - recall: 0.9876 - accuracy: 0.9909 - tversky: 0.9794 - val_loss: 0.1087 - val_iou: 0.9625 - val_dice_coef: 0.9206 - val_precision: 0.9226 - val_recall: 0.9579 - val_accuracy: 0.9614 - val_tversky: 0.9293
# Epoch 52/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.0204 - iou: 0.9916 - dice_coef: 0.9800 - precision: 0.9862 - recall: 0.9879 - accuracy: 0.9917 - tversky: 0.9803 - val_loss: 0.3518 - val_iou: 0.8925 - val_dice_coef: 0.8342 - val_precision: 0.7343 - val_recall: 0.9942 - val_accuracy: 0.8876 - val_tversky: 0.8903
# Epoch 53/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0211 - iou: 0.9913 - dice_coef: 0.9794 - precision: 0.9848 - recall: 0.9878 - accuracy: 0.9914 - tversky: 0.9802 - val_loss: 0.3640 - val_iou: 0.8890 - val_dice_coef: 0.8308 - val_precision: 0.7312 - val_recall: 0.9926 - val_accuracy: 0.8831 - val_tversky: 0.8872
# Epoch 54/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0218 - iou: 0.9911 - dice_coef: 0.9790 - precision: 0.9852 - recall: 0.9870 - accuracy: 0.9912 - tversky: 0.9794 - val_loss: 0.3373 - val_iou: 0.9019 - val_dice_coef: 0.8534 - val_precision: 0.7625 - val_recall: 0.9941 - val_accuracy: 0.9010 - val_tversky: 0.9037
# Epoch 55/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0251 - iou: 0.9898 - dice_coef: 0.9767 - precision: 0.9819 - recall: 0.9866 - accuracy: 0.9900 - tversky: 0.9778 - val_loss: 0.1961 - val_iou: 0.9331 - val_dice_coef: 0.8847 - val_precision: 0.8324 - val_recall: 0.9854 - val_accuracy: 0.9328 - val_tversky: 0.9201
# Epoch 56/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0210 - iou: 0.9915 - dice_coef: 0.9793 - precision: 0.9875 - recall: 0.9859 - accuracy: 0.9915 - tversky: 0.9790 - val_loss: 0.1715 - val_iou: 0.9468 - val_dice_coef: 0.9099 - val_precision: 0.8663 - val_recall: 0.9868 - val_accuracy: 0.9486 - val_tversky: 0.9372
# Epoch 57/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0198 - iou: 0.9920 - dice_coef: 0.9811 - precision: 0.9865 - recall: 0.9884 - accuracy: 0.9919 - tversky: 0.9814 - val_loss: 0.1641 - val_iou: 0.9493 - val_dice_coef: 0.9071 - val_precision: 0.8704 - val_recall: 0.9801 - val_accuracy: 0.9491 - val_tversky: 0.9314
# Epoch 58/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0208 - iou: 0.9915 - dice_coef: 0.9805 - precision: 0.9848 - recall: 0.9886 - accuracy: 0.9916 - tversky: 0.9814 - val_loss: 0.5639 - val_iou: 0.8401 - val_dice_coef: 0.7745 - val_precision: 0.6492 - val_recall: 0.9970 - val_accuracy: 0.8329 - val_tversky: 0.8491
# Epoch 59/60
# 360/360 [==============================] - 8s 23ms/sample - loss: 0.0184 - iou: 0.9924 - dice_coef: 0.9819 - precision: 0.9873 - recall: 0.9890 - accuracy: 0.9925 - tversky: 0.9822 - val_loss: 0.1216 - val_iou: 0.9604 - val_dice_coef: 0.9249 - val_precision: 0.8990 - val_recall: 0.9778 - val_accuracy: 0.9597 - val_tversky: 0.9425
# Epoch 60/60
# 360/360 [==============================] - 8s 22ms/sample - loss: 0.0180 - iou: 0.9926 - dice_coef: 0.9824 - precision: 0.9882 - recall: 0.9889 - accuracy: 0.9926 - tversky: 0.9826 - val_loss: 0.1104 - val_iou: 0.9642 - val_dice_coef: 0.9378 - val_precision: 0.9151 - val_recall: 0.9791 - val_accuracy: 0.9649 - val_tversky: 0.9513

# %%
print('\n~~~~~~~~~~~~~~~Stats after 60 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print('Tversky:   |   {:.2f}  |'.format(res[6]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 60 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 2s 6ms/sample - loss: 0.0594 - iou: 0.9773 - dice_coef: 0.9598 - precision: 0.9416 - recall: 0.9933 - accuracy: 0.9788 - tversky: 0.9710
# ________________________
# IOU:       |   97.73  |
# Dice Coef: |   95.98  |
# Precision: |   94.16  |
# Recall:    |   99.33  |
# Accuracy:  |   97.88  |
# Tversky:   |   97.10  |
# Loss:      |   5.94  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 1s 17ms/sample - loss: 0.1563 - iou: 0.9501 - dice_coef: 0.9170 - precision: 0.8904 - recall: 0.9676 - accuracy: 0.9519 - tversky: 0.9333
# ________________________
# IOU:       |   95.01  |
# Dice Coef: |   91.70  |
# Precision: |   89.04  |
# Recall:    |   96.76  |
# Accuracy:  |   95.19  |
# Tversky:   |   93.33  |
# Loss:      |   15.63  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 1s 6ms/sample - loss: 0.1104 - iou: 0.9642 - dice_coef: 0.9378 - precision: 0.9144 - recall: 0.9799 - accuracy: 0.9649 - tversky: 0.9516
# ________________________
# IOU:       |   96.42  |
# Dice Coef: |   93.78  |
# Precision: |   91.44  |
# Recall:    |   97.99  |
# Accuracy:  |   96.49  |
# Tversky:   |   95.16  |
# Loss:      |   11.04  |
# ________________________

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# #### After 100 epochs

# %% [markdown]
# Testing the statistics after 100 epochs

# %% [markdown]
# ### Plotting Training Statistics

# %% [markdown]
# ## Visualising Predicted Lesions

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model.predict(img.reshape(1,192,256,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# * So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too.

# %% [markdown]
# ### **de nada!**
